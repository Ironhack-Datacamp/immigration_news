# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import total immigrants csv

# %%
immigrants = pd.read_csv('draft_files/migration/total_immigrants_year.csv')

# %%
immigrants
# Out:
#    financial_year  total_immigrants  year_only   t  const
# 0      2002-07-01          125870.0       2002   1      1
# 1      2003-07-01          148431.0       2003   2      1
# 2      2004-07-01          162801.0       2004   3      1
# 3      2005-07-01          174782.0       2005   4      1
# 4      2006-07-01          190864.0       2006   5      1
# 5      2007-07-01          203238.0       2007   6      1
# 6      2008-07-01          219547.0       2008   7      1
# 7      2009-07-01          203647.0       2009   8      1
# 8      2010-07-01          207855.0       2010   9      1
# 9      2011-07-01          237371.0       2011  10      1
# 10     2012-07-01          246454.0       2012  11      1
# 11     2013-07-01          235988.0       2013  12      1
# 12     2014-07-01          225581.0       2014  13      1
# 13     2015-07-01          220100.0       2015  14      1
# 14     2016-07-01          225823.0       2016  15      1

# %%
immigrants.dtypes
# Out:
# financial_year       object
# total_immigrants    float64
# year_only             int64
# t                     int64
# const                 int64
# dtype: object

# %%
immigrants['financial_year'] = pd.to_datetime(immigrants['financial_year'])

# %%
immigrants.dtypes
# Out:
# financial_year      datetime64[ns]
# total_immigrants           float64
# year_only                    int64
# t                            int64
# const                        int64
# dtype: object

# %% [markdown]
# ## import news csv

# %%
news = pd.read_csv('draft_files/abc_news/migr_news_year_percent.csv')

# %%
news
# Out:
#    financial_year  percentage  year_only   t  const
# 0      2002-07-01    0.455606     2002.0   1      1
# 1      2003-07-01    0.498948     2003.0   2      1
# 2      2004-07-01    0.395300     2004.0   3      1
# 3      2005-07-01    0.470755     2005.0   4      1
# 4      2006-07-01    0.360467     2006.0   5      1
# 5      2007-07-01    0.240773     2007.0   6      1
# 6      2008-07-01    0.311291     2008.0   7      1
# 7      2009-07-01    0.577675     2009.0   8      1
# 8      2010-07-01    0.713295     2010.0   9      1
# 9      2011-07-01    0.527310     2011.0  10      1
# 10     2012-07-01    0.676470     2012.0  11      1
# 11     2013-07-01    0.820838     2013.0  12      1
# 12     2014-07-01    0.753584     2014.0  13      1
# 13     2015-07-01    1.159845     2015.0  14      1
# 14     2016-07-01    1.004997     2016.0  15      1
# 15     2017-07-01    0.750633     2017.0  16      1
# 16     2018-07-01    0.836452     2018.0  17      1
# 17     2019-07-01    0.478017     2019.0  18      1

# %%
news.dtypes
# Out:
# financial_year     object
# percentage        float64
# year_only         float64
# t                   int64
# const               int64
# dtype: object

# %%
news['financial_year'] = pd.to_datetime(news['financial_year'])

# %%
news.dtypes
# Out:
# financial_year    datetime64[ns]
# percentage               float64
# year_only                float64
# t                          int64
# const                      int64
# dtype: object

# %%
#df.drop(columns=['B', 'C'])
news = news.drop(columns = ['year_only', 't', 'const'])

# %%
news.dtypes
# Out:
# financial_year    datetime64[ns]
# percentage               float64
# dtype: object

# %% [markdown]
# ## import humanitarian csv

# %%
humanitarian = pd.read_csv('draft_files/humanitarian_data_clean.csv')

# %%
humanitarian.dtypes
# Out:
# Year                             object
# Refugee                         float64
# Special Humanitarian Program    float64
# Special Assistance Category     float64
# Onshore                         float64
# Total                           float64
# year_only                         int64
# dtype: object

# %%
humanitarian['Year'] = pd.to_datetime(humanitarian['Year'])

# %%
humanitarian.dtypes
# Out:
# Year                            datetime64[ns]
# Refugee                                float64
# Special Humanitarian Program           float64
# Special Assistance Category            float64
# Onshore                                float64
# Total                                  float64
# year_only                                int64
# dtype: object

# %%
humanitarian
# Out:
#          Year  Refugee  Special Humanitarian Program  \
# 0  2002-07-01    3.996                         7.212
# 1  2003-07-01    3.851                         8.912
# 2  2004-07-01    5.289                         6.684
# 3  2005-07-01    5.699                         6.739
# 4  2006-07-01    5.924                         5.157
# 5  2007-07-01    5.951                         4.721
# 6  2008-07-01    6.446                         4.471
# 7  2009-07-01    5.988                         3.234
# 8  2010-07-01    5.998                         2.973
# 9  2011-07-01    6.004                       714.000
# 10 2012-07-01   12.012                       503.000
# 11 2013-07-01    6.501                         4.515
# 12 2014-07-01    6.002                         5.007
# 13 2015-07-01    8.284                         7.268
# 14 2016-07-01    9.653                        10.604
# 15 2017-07-01    7.909                         6.916
# 16 2018-07-01    9.451                         7.661
#
#     Special Assistance Category  Onshore   Total  year_only
# 0                           0.0  911.000  12.119       2002
# 1                           0.0  784.000  13.547       2003
# 2                           0.0  952.000  12.925       2004
# 3                           0.0    1.247  13.685       2005
# 4                           0.0    1.707  12.788       2006
# 5                           0.0    1.932  12.604       2007
# 6                           0.0    2.495  13.412       2008
# 7                           0.0    4.535  13.757       2009
# 8                           0.0    4.828  13.799       2010
# 9                           0.0    7.041  13.759       2011
# 10                          0.0    7.504  20.019       2012
# 11                          0.0    2.752  13.768       2013
# 12                          0.0    2.747  13.756       2014
# 13                          0.0    2.003  17.555       2015
# 14                          0.0    1.711  21.968       2016
# 15                          0.0    1.425  16.250       2017
# 16                          0.0    1.650  18.762       2018

# %%
humanit_merge = humanitarian.merge(news_perc, 
                                   left_on='Year', 
                                   right_on='financial_year', copy = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f9ab4ee19ea2> in <module>
# ----> 1 humanit_merge = humanitarian.merge(news_perc,
#       2                                    left_on='Year',
#       3                                    right_on='financial_year', copy = False)
#
# NameError: name 'news_perc' is not defined

# %%
humanit_merge
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-90432fcef0a3> in <module>
# ----> 1 humanit_merge
#
# NameError: name 'humanit_merge' is not defined

# %% [markdown]
# ## Import subregion csv

# %%
subregion = pd.read_csv('draft_files/migration/immigrants_subregion_year.csv')

# %%
subregion
# Out:
#    financial_year  Central Asia  North Africa & the Middle East  \
# 0      2002-07-01        1099.0                         11440.0
# 1      2003-07-01        1410.0                         12203.0
# 2      2004-07-01        1697.0                         13797.0
# 3      2005-07-01        2767.0                         12057.0
# 4      2006-07-01        2460.0                         10845.0
# 5      2007-07-01        1980.0                          9828.0
# 6      2008-07-01        1883.0                         12558.0
# 7      2009-07-01        1770.0                          9936.0
# 8      2010-07-01        2095.0                         11137.0
# 9      2011-07-01        1697.0                         11239.0
# 10     2012-07-01        2119.0                         12558.0
# 11     2013-07-01        4548.0                         14730.0
# 12     2014-07-01        3109.0                         16257.0
# 13     2015-07-01        2963.0                         14429.0
# 14     2016-07-01        3255.0                         28133.0
#
#     North East Asia  North-West Europe  Northern America  Oceania  \
# 0           17084.0            22324.0            3670.0  16775.0
# 1           21171.0            29428.0            4012.0  19131.0
# 2           25342.0            30142.0            4128.0  22263.0
# 3           27540.0            35764.0            4410.0  23963.0
# 4           31584.0            36063.0            4201.0  28392.0
# 5           31172.0            37608.0            4332.0  33308.0
# 6           32609.0            39818.0            4619.0  32515.0
# 7           33166.0            33508.0            4802.0  24685.0
# 8           37147.0            28565.0            4471.0  34060.0
# 9           34705.0            36520.0            4963.0  42925.0
# 10          38053.0            32965.0            5525.0  41694.0
# 11          35359.0            33543.0            5494.0  29304.0
# 12          35787.0            31675.0            5058.0  24610.0
# 13          37080.0            27323.0            4977.0  22845.0
# 14          37235.0            25177.0            4931.0  16449.0
#
#     South America, Central America & the Caribbean  South East Asia  \
# 0                                           1955.0          21037.0
# 1                                           2166.0          22881.0
# 2                                           2392.0          23685.0
# 3                                           2677.0          24463.0
# 4                                           2585.0          26192.0
# 5                                           3046.0          28050.0
# 6                                           3362.0          29994.0
# 7                                           4086.0          30196.0
# 8                                           3479.0          30907.0
# 9                                           4121.0          34324.0
# 10                                          4532.0          34150.0
# 11                                          4438.0          31420.0
# 12                                          4085.0          31720.0
# 13                                          4207.0          32129.0
# 14                                          4788.0          31488.0
#
#     Southern Asia  Southern and Eastern Europe  Sub-Saharan Africa  year_only  \
# 0         12910.0                       6669.0             10907.0       2002
# 1         16662.0                       5846.0             13521.0       2003
# 2         19692.0                       5561.0             14102.0       2004
# 3         22506.0                       5656.0             12979.0       2005
# 4         28476.0                       5502.0             14564.0       2006
# 5         33002.0                       5772.0             15140.0       2007
# 6         36024.0                       6190.0             19975.0       2008
# 7         34761.0                       6079.0             20658.0       2009
# 8         33828.0                       5813.0             16353.0       2010
# 9         43190.0                       6808.0             16879.0       2011
# 10        53429.0                       7785.0             13644.0       2012
# 11        56307.0                       7891.0             12954.0       2013
# 12        52814.0                       7812.0             12654.0       2014
# 13        55328.0                       7400.0             11419.0       2015
# 14        54980.0                       7590.0             11797.0       2016
#
#      t  total_immigrants
# 0    1          125870.0
# 1    2          148431.0
# 2    3          162801.0
# 3    4          174782.0
# 4    5          190864.0
# 5    6          203238.0
# 6    7          219547.0
# 7    8          203647.0
# 8    9          207855.0
# 9   10          237371.0
# 10  11          246454.0
# 11  12          235988.0
# 12  13          225581.0
# 13  14          220100.0
# 14  15          225823.0

# %%
subregion.dtypes
# Out:
# financial_year                                     object
# Central Asia                                      float64
# North Africa & the Middle East                    float64
# North East Asia                                   float64
# North-West Europe                                 float64
# Northern America                                  float64
# Oceania                                           float64
# South America, Central America & the Caribbean    float64
# South East Asia                                   float64
# Southern Asia                                     float64
# Southern and Eastern Europe                       float64
# Sub-Saharan Africa                                float64
# year_only                                           int64
# t                                                   int64
# total_immigrants                                  float64
# dtype: object

# %%
subregion['financial_year'] = pd.to_datetime(subregion['financial_year'])

# %%
subregion.dtypes
# Out:
# financial_year                                    datetime64[ns]
# Central Asia                                             float64
# North Africa & the Middle East                           float64
# North East Asia                                          float64
# North-West Europe                                        float64
# Northern America                                         float64
# Oceania                                                  float64
# South America, Central America & the Caribbean           float64
# South East Asia                                          float64
# Southern Asia                                            float64
# Southern and Eastern Europe                              float64
# Sub-Saharan Africa                                       float64
# year_only                                                  int64
# t                                                          int64
# total_immigrants                                         float64
# dtype: object

# %%
subregion.columns
# Out:
# Index(['financial_year', 'Central Asia', 'North Africa & the Middle East',
#        'North East Asia', 'North-West Europe', 'Northern America', 'Oceania',
#        'South America, Central America & the Caribbean', 'South East Asia',
#        'Southern Asia', 'Southern and Eastern Europe', 'Sub-Saharan Africa',
#        'year_only', 't', 'total_immigrants'],
#       dtype='object')

# %%
news_perc = news[['percentage', 'financial_year']]

# %%
region_merge = subregion.merge(news_perc, left_on='financial_year', right_on='financial_year', copy = False)

# %%
region_merge
# Out:
#    financial_year  Central Asia  North Africa & the Middle East  \
# 0      2002-07-01        1099.0                         11440.0
# 1      2003-07-01        1410.0                         12203.0
# 2      2004-07-01        1697.0                         13797.0
# 3      2005-07-01        2767.0                         12057.0
# 4      2006-07-01        2460.0                         10845.0
# 5      2007-07-01        1980.0                          9828.0
# 6      2008-07-01        1883.0                         12558.0
# 7      2009-07-01        1770.0                          9936.0
# 8      2010-07-01        2095.0                         11137.0
# 9      2011-07-01        1697.0                         11239.0
# 10     2012-07-01        2119.0                         12558.0
# 11     2013-07-01        4548.0                         14730.0
# 12     2014-07-01        3109.0                         16257.0
# 13     2015-07-01        2963.0                         14429.0
# 14     2016-07-01        3255.0                         28133.0
#
#     North East Asia  North-West Europe  Northern America  Oceania  \
# 0           17084.0            22324.0            3670.0  16775.0
# 1           21171.0            29428.0            4012.0  19131.0
# 2           25342.0            30142.0            4128.0  22263.0
# 3           27540.0            35764.0            4410.0  23963.0
# 4           31584.0            36063.0            4201.0  28392.0
# 5           31172.0            37608.0            4332.0  33308.0
# 6           32609.0            39818.0            4619.0  32515.0
# 7           33166.0            33508.0            4802.0  24685.0
# 8           37147.0            28565.0            4471.0  34060.0
# 9           34705.0            36520.0            4963.0  42925.0
# 10          38053.0            32965.0            5525.0  41694.0
# 11          35359.0            33543.0            5494.0  29304.0
# 12          35787.0            31675.0            5058.0  24610.0
# 13          37080.0            27323.0            4977.0  22845.0
# 14          37235.0            25177.0            4931.0  16449.0
#
#     South America, Central America & the Caribbean  South East Asia  \
# 0                                           1955.0          21037.0
# 1                                           2166.0          22881.0
# 2                                           2392.0          23685.0
# 3                                           2677.0          24463.0
# 4                                           2585.0          26192.0
# 5                                           3046.0          28050.0
# 6                                           3362.0          29994.0
# 7                                           4086.0          30196.0
# 8                                           3479.0          30907.0
# 9                                           4121.0          34324.0
# 10                                          4532.0          34150.0
# 11                                          4438.0          31420.0
# 12                                          4085.0          31720.0
# 13                                          4207.0          32129.0
# 14                                          4788.0          31488.0
#
#     Southern Asia  Southern and Eastern Europe  Sub-Saharan Africa  year_only  \
# 0         12910.0                       6669.0             10907.0       2002
# 1         16662.0                       5846.0             13521.0       2003
# 2         19692.0                       5561.0             14102.0       2004
# 3         22506.0                       5656.0             12979.0       2005
# 4         28476.0                       5502.0             14564.0       2006
# 5         33002.0                       5772.0             15140.0       2007
# 6         36024.0                       6190.0             19975.0       2008
# 7         34761.0                       6079.0             20658.0       2009
# 8         33828.0                       5813.0             16353.0       2010
# 9         43190.0                       6808.0             16879.0       2011
# 10        53429.0                       7785.0             13644.0       2012
# 11        56307.0                       7891.0             12954.0       2013
# 12        52814.0                       7812.0             12654.0       2014
# 13        55328.0                       7400.0             11419.0       2015
# 14        54980.0                       7590.0             11797.0       2016
#
#      t  total_immigrants  percentage
# 0    1          125870.0    0.455606
# 1    2          148431.0    0.498948
# 2    3          162801.0    0.395300
# 3    4          174782.0    0.470755
# 4    5          190864.0    0.360467
# 5    6          203238.0    0.240773
# 6    7          219547.0    0.311291
# 7    8          203647.0    0.577675
# 8    9          207855.0    0.713295
# 9   10          237371.0    0.527310
# 10  11          246454.0    0.676470
# 11  12          235988.0    0.820838
# 12  13          225581.0    0.753584
# 13  14          220100.0    1.159845
# 14  15          225823.0    1.004997

# %% [markdown]
# ## Merge

# %%
merged = immigrants.merge(news, left_on='financial_year', right_on='financial_year', copy = False)

# %%
merged.dtypes
# Out:
# financial_year      datetime64[ns]
# total_immigrants           float64
# year_only                    int64
# t                            int64
# const                        int64
# percentage                 float64
# dtype: object

# %%
merged
# Out:
#    financial_year  total_immigrants  year_only   t  const  percentage
# 0      2002-07-01          125870.0       2002   1      1    0.455606
# 1      2003-07-01          148431.0       2003   2      1    0.498948
# 2      2004-07-01          162801.0       2004   3      1    0.395300
# 3      2005-07-01          174782.0       2005   4      1    0.470755
# 4      2006-07-01          190864.0       2006   5      1    0.360467
# 5      2007-07-01          203238.0       2007   6      1    0.240773
# 6      2008-07-01          219547.0       2008   7      1    0.311291
# 7      2009-07-01          203647.0       2009   8      1    0.577675
# 8      2010-07-01          207855.0       2010   9      1    0.713295
# 9      2011-07-01          237371.0       2011  10      1    0.527310
# 10     2012-07-01          246454.0       2012  11      1    0.676470
# 11     2013-07-01          235988.0       2013  12      1    0.820838
# 12     2014-07-01          225581.0       2014  13      1    0.753584
# 13     2015-07-01          220100.0       2015  14      1    1.159845
# 14     2016-07-01          225823.0       2016  15      1    1.004997

# %%
merged = merged.rename(columns={'percentage': 'migr_news_perc'})

# %%
merged.columns
# Out:
# Index(['financial_year', 'total_immigrants', 'year_only', 't', 'const',
#        'migr_news_perc'],
#       dtype='object')

# %%
merged = merged[['financial_year', 'total_immigrants', 
                 'migr_news_perc', 'year_only', 't', 'const']]

# %%
merged
# Out:
#    financial_year  total_immigrants  migr_news_perc  year_only   t  const
# 0      2002-07-01          125870.0        0.455606       2002   1      1
# 1      2003-07-01          148431.0        0.498948       2003   2      1
# 2      2004-07-01          162801.0        0.395300       2004   3      1
# 3      2005-07-01          174782.0        0.470755       2005   4      1
# 4      2006-07-01          190864.0        0.360467       2006   5      1
# 5      2007-07-01          203238.0        0.240773       2007   6      1
# 6      2008-07-01          219547.0        0.311291       2008   7      1
# 7      2009-07-01          203647.0        0.577675       2009   8      1
# 8      2010-07-01          207855.0        0.713295       2010   9      1
# 9      2011-07-01          237371.0        0.527310       2011  10      1
# 10     2012-07-01          246454.0        0.676470       2012  11      1
# 11     2013-07-01          235988.0        0.820838       2013  12      1
# 12     2014-07-01          225581.0        0.753584       2014  13      1
# 13     2015-07-01          220100.0        1.159845       2015  14      1
# 14     2016-07-01          225823.0        1.004997       2016  15      1

# %% [markdown]
# # Regressions

# %%
ax = merged.plot(x="year_only", y="total_immigrants", legend=False)
ax2 = ax.twinx()
merged.plot(x="year_only", y="migr_news_perc", ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()

plt.show()

# %%
ax = merged.plot(x="year_only", y="total_immigrants", legend=False)
ax2 = ax.twinx()
merged.plot(x="year_only", y="migr_news_perc", ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()



plt.show()

# %%
ax = merged.plot(x="year_only", y="total_immigrants", legend=False)
ax2 = ax.twinx()
merged.plot(x="year_only", y="migr_news_perc", ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()
ax.set_ylim(bottom=0)
plt.show()

# %% [markdown]
# - both general upward trend
# - but looks inverse: when there are less migration news stories, there are more immigrants, when there are more migration news stories, there are less immigrants
# - or time lag? .. but of 2 years?
# - don't know which one comes first:
#     - are there a lot of immigrants, then a lot of news about immigrants?
#     - is there a lot of news about immigrants, followed by stricter policies/less immigrants?
#     - is there actually any correlation?

# %%
#regression
y = merged["total_immigrants"]
X = merged[["const", "t", 'migr_news_perc']] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# /Users/imogen/opt/anaconda3/envs/matrix/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       total_immigrants   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                     68.98
# Date:                Mon, 05 Oct 2020   Prob (F-statistic):           2.63e-07
# Time:                        16:33:16   Log-Likelihood:                -158.81
# No. Observations:                  15   AIC:                             323.6
# Df Residuals:                      12   BIC:                             325.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1.681e+05   7195.748     23.368      0.000    1.52e+05    1.84e+05
# t               1.105e+04   1066.883     10.354      0.000    8721.837    1.34e+04
# migr_news_perc -9.138e+04   1.85e+04     -4.946      0.000   -1.32e+05   -5.11e+04
# ==============================================================================
# Omnibus:                        0.291   Durbin-Watson:                   1.742
# Prob(Omnibus):                  0.865   Jarque-Bera (JB):                0.320
# Skew:                          -0.264   Prob(JB):                        0.852
# Kurtosis:                       2.518   Cond. No.                         62.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#regression
y = merged["migr_news_perc"]
X = merged[["const", "t", 'total_immigrants']] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         migr_news_perc   R-squared:                       0.881
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     44.52
# Date:                Mon, 05 Oct 2020   Prob (F-statistic):           2.81e-06
# Time:                        16:33:34   Log-Likelihood:                 15.521
# No. Observations:                  15   AIC:                            -25.04
# Df Residuals:                      12   BIC:                            -22.92
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.3097      0.225      5.827      0.000       0.820       1.799
# t                    0.0963      0.012      8.266      0.000       0.071       0.122
# total_immigrants -7.342e-06   1.48e-06     -4.946      0.000   -1.06e-05   -4.11e-06
# ==============================================================================
# Omnibus:                        0.909   Durbin-Watson:                   2.342
# Prob(Omnibus):                  0.635   Jarque-Bera (JB):                0.800
# Skew:                          -0.334   Prob(JB):                        0.670
# Kurtosis:                       2.086   Cond. No.                     1.86e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.86e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#regression
y = merged["total_immigrants"]
X = merged[["const", 'migr_news_perc']] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# /Users/imogen/opt/anaconda3/envs/matrix/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       total_immigrants   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.144
# Method:                 Least Squares   F-statistic:                     3.354
# Date:                Tue, 06 Oct 2020   Prob (F-statistic):             0.0901
# Time:                        14:24:09   Log-Likelihood:                -176.03
# No. Observations:                  15   AIC:                             356.1
# Df Residuals:                      13   BIC:                             357.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1.651e+05   2.18e+04      7.583      0.000    1.18e+05    2.12e+05
# migr_news_perc  6.155e+04   3.36e+04      1.831      0.090   -1.11e+04    1.34e+05
# ==============================================================================
# Omnibus:                        1.471   Durbin-Watson:                   0.456
# Prob(Omnibus):                  0.479   Jarque-Bera (JB):                0.964
# Skew:                          -0.597   Prob(JB):                        0.617
# Kurtosis:                       2.657   Cond. No.                         5.51
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## humanitarian & news

# %%
humanit_merge.head()
# Out:
#         Year  Refugee  Special Humanitarian Program  \
# 0 2002-07-01    3.996                         7.212
# 1 2003-07-01    3.851                         8.912
# 2 2004-07-01    5.289                         6.684
# 3 2005-07-01    5.699                         6.739
# 4 2006-07-01    5.924                         5.157
#
#    Special Assistance Category  Onshore   Total  year_only  percentage  \
# 0                          0.0  911.000  12.119       2002    0.455606
# 1                          0.0  784.000  13.547       2003    0.498948
# 2                          0.0  952.000  12.925       2004    0.395300
# 3                          0.0    1.247  13.685       2005    0.470755
# 4                          0.0    1.707  12.788       2006    0.360467
#
#   financial_year
# 0     2002-07-01
# 1     2003-07-01
# 2     2004-07-01
# 3     2005-07-01
# 4     2006-07-01

# %%
#add 't' column
humanit_merge = (humanit_merge
                .sort_values("Year")
                .assign(t=range(1, len(humanit_merge)+1)))

# %%
#add constant
humanit_merge = humanit_merge.assign(const=1)
#regression
y = humanit_merge["Total"]
X = humanit_merge[["const", "t", 'percentage']] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# /Users/imogen/opt/anaconda3/envs/matrix/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Total   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                     9.272
# Date:                Tue, 06 Oct 2020   Prob (F-statistic):            0.00273
# Time:                        11:11:33   Log-Likelihood:                -34.448
# No. Observations:                  17   AIC:                             74.90
# Df Residuals:                      14   BIC:                             77.40
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.0605      1.352      7.441      0.000       7.161      12.960
# t              0.2283      0.162      1.411      0.180      -0.119       0.575
# percentage     4.5968      3.260      1.410      0.180      -2.396      11.590
# ==============================================================================
# Omnibus:                        4.676   Durbin-Watson:                   2.387
# Prob(Omnibus):                  0.097   Jarque-Bera (JB):                2.419
# Skew:                           0.864   Prob(JB):                        0.298
# Kurtosis:                       3.656   Cond. No.                         71.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
humanit_merge
# Out:
#          Year  Refugee  Special Humanitarian Program  \
# 0  2002-07-01    3.996                         7.212
# 1  2003-07-01    3.851                         8.912
# 2  2004-07-01    5.289                         6.684
# 3  2005-07-01    5.699                         6.739
# 4  2006-07-01    5.924                         5.157
# 5  2007-07-01    5.951                         4.721
# 6  2008-07-01    6.446                         4.471
# 7  2009-07-01    5.988                         3.234
# 8  2010-07-01    5.998                         2.973
# 9  2011-07-01    6.004                       714.000
# 10 2012-07-01   12.012                       503.000
# 11 2013-07-01    6.501                         4.515
# 12 2014-07-01    6.002                         5.007
# 13 2015-07-01    8.284                         7.268
# 14 2016-07-01    9.653                        10.604
# 15 2017-07-01    7.909                         6.916
# 16 2018-07-01    9.451                         7.661
#
#     Special Assistance Category  Onshore   Total  year_only  percentage  \
# 0                           0.0  911.000  12.119       2002    0.455606
# 1                           0.0  784.000  13.547       2003    0.498948
# 2                           0.0  952.000  12.925       2004    0.395300
# 3                           0.0    1.247  13.685       2005    0.470755
# 4                           0.0    1.707  12.788       2006    0.360467
# 5                           0.0    1.932  12.604       2007    0.240773
# 6                           0.0    2.495  13.412       2008    0.311291
# 7                           0.0    4.535  13.757       2009    0.577675
# 8                           0.0    4.828  13.799       2010    0.713295
# 9                           0.0    7.041  13.759       2011    0.527310
# 10                          0.0    7.504  20.019       2012    0.676470
# 11                          0.0    2.752  13.768       2013    0.820838
# 12                          0.0    2.747  13.756       2014    0.753584
# 13                          0.0    2.003  17.555       2015    1.159845
# 14                          0.0    1.711  21.968       2016    1.004997
# 15                          0.0    1.425  16.250       2017    0.750633
# 16                          0.0    1.650  18.762       2018    0.836452
#
#    financial_year
# 0      2002-07-01
# 1      2003-07-01
# 2      2004-07-01
# 3      2005-07-01
# 4      2006-07-01
# 5      2007-07-01
# 6      2008-07-01
# 7      2009-07-01
# 8      2010-07-01
# 9      2011-07-01
# 10     2012-07-01
# 11     2013-07-01
# 12     2014-07-01
# 13     2015-07-01
# 14     2016-07-01
# 15     2017-07-01
# 16     2018-07-01

# %%
humanit_merge_early = humanit_merge.loc[(humanit_merge['year_only'] 
                                         < 2011)]
humanit_merge_early
# Out:
#         Year  Refugee  Special Humanitarian Program  \
# 0 2002-07-01    3.996                         7.212
# 1 2003-07-01    3.851                         8.912
# 2 2004-07-01    5.289                         6.684
# 3 2005-07-01    5.699                         6.739
# 4 2006-07-01    5.924                         5.157
# 5 2007-07-01    5.951                         4.721
# 6 2008-07-01    6.446                         4.471
# 7 2009-07-01    5.988                         3.234
# 8 2010-07-01    5.998                         2.973
#
#    Special Assistance Category  Onshore   Total  year_only  percentage  \
# 0                          0.0  911.000  12.119       2002    0.455606
# 1                          0.0  784.000  13.547       2003    0.498948
# 2                          0.0  952.000  12.925       2004    0.395300
# 3                          0.0    1.247  13.685       2005    0.470755
# 4                          0.0    1.707  12.788       2006    0.360467
# 5                          0.0    1.932  12.604       2007    0.240773
# 6                          0.0    2.495  13.412       2008    0.311291
# 7                          0.0    4.535  13.757       2009    0.577675
# 8                          0.0    4.828  13.799       2010    0.713295
#
#   financial_year
# 0     2002-07-01
# 1     2003-07-01
# 2     2004-07-01
# 3     2005-07-01
# 4     2006-07-01
# 5     2007-07-01
# 6     2008-07-01
# 7     2009-07-01
# 8     2010-07-01

# %%
humanit_merge_late = humanit_merge.loc[(humanit_merge['year_only'] 
                                         > 2010)]
humanit_merge_late = humanit_merge_late.reset_index(drop=True)
humanit_merge_late
# Out:
#         Year  Refugee  Special Humanitarian Program  \
# 0 2011-07-01    6.004                       714.000
# 1 2012-07-01   12.012                       503.000
# 2 2013-07-01    6.501                         4.515
# 3 2014-07-01    6.002                         5.007
# 4 2015-07-01    8.284                         7.268
# 5 2016-07-01    9.653                        10.604
# 6 2017-07-01    7.909                         6.916
# 7 2018-07-01    9.451                         7.661
#
#    Special Assistance Category  Onshore   Total  year_only  percentage  \
# 0                          0.0    7.041  13.759       2011    0.527310
# 1                          0.0    7.504  20.019       2012    0.676470
# 2                          0.0    2.752  13.768       2013    0.820838
# 3                          0.0    2.747  13.756       2014    0.753584
# 4                          0.0    2.003  17.555       2015    1.159845
# 5                          0.0    1.711  21.968       2016    1.004997
# 6                          0.0    1.425  16.250       2017    0.750633
# 7                          0.0    1.650  18.762       2018    0.836452
#
#   financial_year
# 0     2011-07-01
# 1     2012-07-01
# 2     2013-07-01
# 3     2014-07-01
# 4     2015-07-01
# 5     2016-07-01
# 6     2017-07-01
# 7     2018-07-01

# %%
ax = humanit_merge_early.plot(x="year_only", y="Total", legend=False)
ax2 = ax.twinx()
humanit_merge_early.plot(x="year_only", y="percentage", 
                   ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()
plt.show()

# %%
#add constant
humanit_merge_early = humanit_merge_early.assign(const=1)

#regression
y = humanit_merge_early['percentage']
X = humanit_merge_early[["const", 'Total']] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.341
# Model:                            OLS   Adj. R-squared:                  0.247
# Method:                 Least Squares   F-statistic:                     3.629
# Date:                Wed, 07 Oct 2020   Prob (F-statistic):             0.0985
# Time:                        10:24:31   Log-Likelihood:                 7.1753
# No. Observations:                   9   AIC:                            -10.35
# Df Residuals:                       7   BIC:                            -9.956
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.3963      0.969     -1.442      0.193      -3.687       0.894
# Total          0.1398      0.073      1.905      0.098      -0.034       0.313
# ==============================================================================
# Omnibus:                        0.244   Durbin-Watson:                   0.944
# Prob(Omnibus):                  0.885   Jarque-Bera (JB):                0.378
# Skew:                           0.254   Prob(JB):                        0.828
# Kurtosis:                       2.134   Cond. No.                         312.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
ax = humanit_merge_late.plot(x="year_only", y="Total", legend=False)
ax2 = ax.twinx()
humanit_merge_late.plot(x="year_only", y="percentage", 
                   ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()
plt.show()

# %%
#add constant
humanit_merge_late = humanit_merge_late.assign(const=1)

#regression
y = humanit_merge_late['percentage']
X = humanit_merge_late[["const", 'Total']] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# /Users/imogen/opt/anaconda3/envs/matrix/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=8
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     1.498
# Date:                Wed, 07 Oct 2020   Prob (F-statistic):              0.267
# Time:                        10:24:52   Log-Likelihood:                 3.1644
# No. Observations:                   8   AIC:                            -2.329
# Df Residuals:                       6   BIC:                            -2.170
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3464      0.390      0.889      0.408      -0.607       1.300
# Total          0.0277      0.023      1.224      0.267      -0.028       0.083
# ==============================================================================
# Omnibus:                        1.276   Durbin-Watson:                   1.331
# Prob(Omnibus):                  0.528   Jarque-Bera (JB):                0.330
# Skew:                           0.486   Prob(JB):                        0.848
# Kurtosis:                       2.789   Cond. No.                         101.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
ax = humanit_merge.plot(x="year_only", y="Total", legend=False)
ax2 = ax.twinx()
humanit_merge.plot(x="year_only", y="percentage", 
                   ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()
plt.show()

# %%
ax = humanit_merge.plot(x="year_only", y="Special Humanitarian Program", legend=False)
ax2 = ax.twinx()
humanit_merge.plot(x="year_only", y="percentage", 
                   ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()
plt.show()

# %%
ax = humanit_merge.plot(x="year_only", y="Refugee", legend=False)
ax2 = ax.twinx()
humanit_merge.plot(x="year_only", y="percentage", 
                   ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()
plt.show()

# %%
ax = humanit_merge.plot(x="year_only", y="Onshore", legend=False)
ax2 = ax.twinx()
humanit_merge.plot(x="year_only", y="percentage", 
                   ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()
plt.show()

# %%
ax = humanit_merge.plot(x="year_only", y="Refugee", legend=False)
ax2 = ax.twinx()
humanit_merge.plot(x="year_only", y="percentage", 
                   ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()
plt.show()

# %%
#add constant
humanit_merge = humanit_merge.assign(const=1)
#regression
y = humanit_merge['percentage']
X = humanit_merge[["const", "t", 'Onshore']] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.678
# Model:                            OLS   Adj. R-squared:                  0.632
# Method:                 Least Squares   F-statistic:                     14.74
# Date:                Tue, 06 Oct 2020   Prob (F-statistic):           0.000359
# Time:                        12:41:16   Log-Likelihood:                 9.5497
# No. Observations:                  17   AIC:                            -13.10
# Df Residuals:                      14   BIC:                            -10.60
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1362      0.113      1.209      0.247      -0.105       0.378
# t              0.0497      0.010      4.972      0.000       0.028       0.071
# Onshore        0.0002      0.000      1.628      0.126   -7.51e-05       0.001
# ==============================================================================
# Omnibus:                        0.845   Durbin-Watson:                   1.734
# Prob(Omnibus):                  0.655   Jarque-Bera (JB):                0.566
# Skew:                           0.420   Prob(JB):                        0.753
# Kurtosis:                       2.696   Cond. No.                     1.14e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.14e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#add constant
humanit_merge = humanit_merge.assign(const=1)
#regression
y = humanit_merge[""]
X = humanit_merge[["const", "t", 'percentage']] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()

# %%
#sum up the columns for each row
# make new totals column
#delete the

# %%
humanit_merge
# Out:
#          Year  Refugee  Special Humanitarian Program  \
# 0  2002-07-01    3.996                         7.212
# 1  2003-07-01    3.851                         8.912
# 2  2004-07-01    5.289                         6.684
# 3  2005-07-01    5.699                         6.739
# 4  2006-07-01    5.924                         5.157
# 5  2007-07-01    5.951                         4.721
# 6  2008-07-01    6.446                         4.471
# 7  2009-07-01    5.988                         3.234
# 8  2010-07-01    5.998                         2.973
# 9  2011-07-01    6.004                       714.000
# 10 2012-07-01   12.012                       503.000
# 11 2013-07-01    6.501                         4.515
# 12 2014-07-01    6.002                         5.007
# 13 2015-07-01    8.284                         7.268
# 14 2016-07-01    9.653                        10.604
# 15 2017-07-01    7.909                         6.916
# 16 2018-07-01    9.451                         7.661
#
#     Special Assistance Category  Onshore   Total  year_only  percentage  \
# 0                           0.0  911.000  12.119       2002    0.455606
# 1                           0.0  784.000  13.547       2003    0.498948
# 2                           0.0  952.000  12.925       2004    0.395300
# 3                           0.0    1.247  13.685       2005    0.470755
# 4                           0.0    1.707  12.788       2006    0.360467
# 5                           0.0    1.932  12.604       2007    0.240773
# 6                           0.0    2.495  13.412       2008    0.311291
# 7                           0.0    4.535  13.757       2009    0.577675
# 8                           0.0    4.828  13.799       2010    0.713295
# 9                           0.0    7.041  13.759       2011    0.527310
# 10                          0.0    7.504  20.019       2012    0.676470
# 11                          0.0    2.752  13.768       2013    0.820838
# 12                          0.0    2.747  13.756       2014    0.753584
# 13                          0.0    2.003  17.555       2015    1.159845
# 14                          0.0    1.711  21.968       2016    1.004997
# 15                          0.0    1.425  16.250       2017    0.750633
# 16                          0.0    1.650  18.762       2018    0.836452
#
#    financial_year  const   t
# 0      2002-07-01      1   1
# 1      2003-07-01      1   2
# 2      2004-07-01      1   3
# 3      2005-07-01      1   4
# 4      2006-07-01      1   5
# 5      2007-07-01      1   6
# 6      2008-07-01      1   7
# 7      2009-07-01      1   8
# 8      2010-07-01      1   9
# 9      2011-07-01      1  10
# 10     2012-07-01      1  11
# 11     2013-07-01      1  12
# 12     2014-07-01      1  13
# 13     2015-07-01      1  14
# 14     2016-07-01      1  15
# 15     2017-07-01      1  16
# 16     2018-07-01      1  17

# %%
#deving_merge['Central Asia']

# %%
#subregion = migration_copy.groupby('sub-region').sum()

# %%
'''subregion = migration_copy.groupby('sub-region').sum()
migration['2008–09'].sum()
numbers_per_year = [migration.sum(numeric_only=True)]
df = pd.DataFrame (numbers_per_year)
df = df.T # transpose
df'''

# %%
deving_merge
# Out:
#    financial_year  Central Asia  North Africa & the Middle East  \
# 0      2002-07-01        1099.0                         11440.0
# 1      2003-07-01        1410.0                         12203.0
# 2      2004-07-01        1697.0                         13797.0
# 3      2005-07-01        2767.0                         12057.0
# 4      2006-07-01        2460.0                         10845.0
# 5      2007-07-01        1980.0                          9828.0
# 6      2008-07-01        1883.0                         12558.0
# 7      2009-07-01        1770.0                          9936.0
# 8      2010-07-01        2095.0                         11137.0
# 9      2011-07-01        1697.0                         11239.0
# 10     2012-07-01        2119.0                         12558.0
# 11     2013-07-01        4548.0                         14730.0
# 12     2014-07-01        3109.0                         16257.0
# 13     2015-07-01        2963.0                         14429.0
# 14     2016-07-01        3255.0                         28133.0
#
#     South America, Central America & the Caribbean  South East Asia  \
# 0                                           1955.0          21037.0
# 1                                           2166.0          22881.0
# 2                                           2392.0          23685.0
# 3                                           2677.0          24463.0
# 4                                           2585.0          26192.0
# 5                                           3046.0          28050.0
# 6                                           3362.0          29994.0
# 7                                           4086.0          30196.0
# 8                                           3479.0          30907.0
# 9                                           4121.0          34324.0
# 10                                          4532.0          34150.0
# 11                                          4438.0          31420.0
# 12                                          4085.0          31720.0
# 13                                          4207.0          32129.0
# 14                                          4788.0          31488.0
#
#     Southern Asia  Sub-Saharan Africa  year_only   t  total_immigrants  \
# 0         12910.0             10907.0       2002   1          125870.0
# 1         16662.0             13521.0       2003   2          148431.0
# 2         19692.0             14102.0       2004   3          162801.0
# 3         22506.0             12979.0       2005   4          174782.0
# 4         28476.0             14564.0       2006   5          190864.0
# 5         33002.0             15140.0       2007   6          203238.0
# 6         36024.0             19975.0       2008   7          219547.0
# 7         34761.0             20658.0       2009   8          203647.0
# 8         33828.0             16353.0       2010   9          207855.0
# 9         43190.0             16879.0       2011  10          237371.0
# 10        53429.0             13644.0       2012  11          246454.0
# 11        56307.0             12954.0       2013  12          235988.0
# 12        52814.0             12654.0       2014  13          225581.0
# 13        55328.0             11419.0       2015  14          220100.0
# 14        54980.0             11797.0       2016  15          225823.0
#
#     percentage
# 0     0.455606
# 1     0.498948
# 2     0.395300
# 3     0.470755
# 4     0.360467
# 5     0.240773
# 6     0.311291
# 7     0.577675
# 8     0.713295
# 9     0.527310
# 10    0.676470
# 11    0.820838
# 12    0.753584
# 13    1.159845
# 14    1.004997

# %%
ax = deving_merge.plot(x="year_only", y="North Africa & the Middle East", legend=False)
ax2 = ax.twinx()
deving_merge.plot(x="year_only", y="percentage", ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()
plt.show()

# %% [markdown]
# above looks like a very close fit, but regression is not statistically significant.

# %%
#add constant
deving_merge = deving_merge.assign(const=1)
#regression
y = deving_merge["North Africa & the Middle East"]
X = deving_merge[["const", "t", 'percentage']] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     North Africa & the Middle East   R-squared:                       0.392
# Model:                                        OLS   Adj. R-squared:                  0.291
# Method:                             Least Squares   F-statistic:                     3.871
# Date:                            Mon, 05 Oct 2020   Prob (F-statistic):             0.0504
# Time:                                    17:44:07   Log-Likelihood:                -143.06
# No. Observations:                              15   AIC:                             292.1
# Df Residuals:                                  12   BIC:                             294.2
# Df Model:                                       2
# Covariance Type:                        nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7184.4804   2516.807      2.855      0.014    1700.829    1.27e+04
# t            234.8483    373.156      0.629      0.541    -578.189    1047.886
# percentage  7270.7574   6462.194      1.125      0.283   -6809.153    2.14e+04
# ==============================================================================
# Omnibus:                       14.497   Durbin-Watson:                   1.670
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               11.437
# Skew:                           1.559   Prob(JB):                      0.00328
# Kurtosis:                       5.929   Cond. No.                         62.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#add constant
deving_merge = deving_merge.assign(const=1)
#regression
y = deving_merge['percentage']
X = deving_merge[["const", "t", "North Africa & the Middle East"]] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.619
# Method:                 Least Squares   F-statistic:                     12.38
# Date:                Mon, 05 Oct 2020   Prob (F-statistic):            0.00121
# Time:                        17:32:04   Log-Likelihood:                 7.9377
# No. Observations:                  15   AIC:                            -9.875
# Df Residuals:                      12   BIC:                            -7.751
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              0.1124      0.135      0.834      0.420      -0.181       0.406
# t                                  0.0387      0.012      3.329      0.006       0.013       0.064
# North Africa & the Middle East  1.312e-05   1.17e-05      1.125      0.283   -1.23e-05    3.85e-05
# ==============================================================================
# Omnibus:                        0.541   Durbin-Watson:                   1.702
# Prob(Omnibus):                  0.763   Jarque-Bera (JB):                0.185
# Skew:                           0.261   Prob(JB):                        0.912
# Kurtosis:                       2.846   Cond. No.                     4.61e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.61e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
ax = deving_merge.plot(x="year_only", y="Sub-Saharan Africa", legend=False)
ax2 = ax.twinx()
deving_merge.plot(x="year_only", y="percentage", ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()
plt.show()

# %%
#add constant
deving_merge = deving_merge.assign(const=1)
#regression
y = deving_merge['percentage']
X = deving_merge[["const", "t", "Sub-Saharan Africa"]] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     20.14
# Date:                Mon, 05 Oct 2020   Prob (F-statistic):           0.000146
# Time:                        17:44:46   Log-Likelihood:                 10.579
# No. Observations:                  15   AIC:                            -15.16
# Df Residuals:                      12   BIC:                            -13.03
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.7153      0.199      3.586      0.004       0.281       1.150
# t                      0.0442      0.008      5.515      0.000       0.027       0.062
# Sub-Saharan Africa  -3.25e-05   1.24e-05     -2.620      0.022   -5.95e-05   -5.48e-06
# ==============================================================================
# Omnibus:                        0.019   Durbin-Watson:                   1.660
# Prob(Omnibus):                  0.991   Jarque-Bera (JB):                0.218
# Skew:                          -0.055   Prob(JB):                        0.897
# Kurtosis:                       2.420   Cond. No.                     8.54e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.54e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### Visually looks like a strong correlation between news stories on immigrants and immigration from MENA region, but not statistically significant

# %%
region_merge
# Out:
#    financial_year  Central Asia  North Africa & the Middle East  \
# 0      2002-07-01        1099.0                         11440.0
# 1      2003-07-01        1410.0                         12203.0
# 2      2004-07-01        1697.0                         13797.0
# 3      2005-07-01        2767.0                         12057.0
# 4      2006-07-01        2460.0                         10845.0
# 5      2007-07-01        1980.0                          9828.0
# 6      2008-07-01        1883.0                         12558.0
# 7      2009-07-01        1770.0                          9936.0
# 8      2010-07-01        2095.0                         11137.0
# 9      2011-07-01        1697.0                         11239.0
# 10     2012-07-01        2119.0                         12558.0
# 11     2013-07-01        4548.0                         14730.0
# 12     2014-07-01        3109.0                         16257.0
# 13     2015-07-01        2963.0                         14429.0
# 14     2016-07-01        3255.0                         28133.0
#
#     North East Asia  North-West Europe  Northern America  Oceania  \
# 0           17084.0            22324.0            3670.0  16775.0
# 1           21171.0            29428.0            4012.0  19131.0
# 2           25342.0            30142.0            4128.0  22263.0
# 3           27540.0            35764.0            4410.0  23963.0
# 4           31584.0            36063.0            4201.0  28392.0
# 5           31172.0            37608.0            4332.0  33308.0
# 6           32609.0            39818.0            4619.0  32515.0
# 7           33166.0            33508.0            4802.0  24685.0
# 8           37147.0            28565.0            4471.0  34060.0
# 9           34705.0            36520.0            4963.0  42925.0
# 10          38053.0            32965.0            5525.0  41694.0
# 11          35359.0            33543.0            5494.0  29304.0
# 12          35787.0            31675.0            5058.0  24610.0
# 13          37080.0            27323.0            4977.0  22845.0
# 14          37235.0            25177.0            4931.0  16449.0
#
#     South America, Central America & the Caribbean  South East Asia  \
# 0                                           1955.0          21037.0
# 1                                           2166.0          22881.0
# 2                                           2392.0          23685.0
# 3                                           2677.0          24463.0
# 4                                           2585.0          26192.0
# 5                                           3046.0          28050.0
# 6                                           3362.0          29994.0
# 7                                           4086.0          30196.0
# 8                                           3479.0          30907.0
# 9                                           4121.0          34324.0
# 10                                          4532.0          34150.0
# 11                                          4438.0          31420.0
# 12                                          4085.0          31720.0
# 13                                          4207.0          32129.0
# 14                                          4788.0          31488.0
#
#     Southern Asia  Southern and Eastern Europe  Sub-Saharan Africa  year_only  \
# 0         12910.0                       6669.0             10907.0       2002
# 1         16662.0                       5846.0             13521.0       2003
# 2         19692.0                       5561.0             14102.0       2004
# 3         22506.0                       5656.0             12979.0       2005
# 4         28476.0                       5502.0             14564.0       2006
# 5         33002.0                       5772.0             15140.0       2007
# 6         36024.0                       6190.0             19975.0       2008
# 7         34761.0                       6079.0             20658.0       2009
# 8         33828.0                       5813.0             16353.0       2010
# 9         43190.0                       6808.0             16879.0       2011
# 10        53429.0                       7785.0             13644.0       2012
# 11        56307.0                       7891.0             12954.0       2013
# 12        52814.0                       7812.0             12654.0       2014
# 13        55328.0                       7400.0             11419.0       2015
# 14        54980.0                       7590.0             11797.0       2016
#
#      t  total_immigrants  percentage
# 0    1          125870.0    0.455606
# 1    2          148431.0    0.498948
# 2    3          162801.0    0.395300
# 3    4          174782.0    0.470755
# 4    5          190864.0    0.360467
# 5    6          203238.0    0.240773
# 6    7          219547.0    0.311291
# 7    8          203647.0    0.577675
# 8    9          207855.0    0.713295
# 9   10          237371.0    0.527310
# 10  11          246454.0    0.676470
# 11  12          235988.0    0.820838
# 12  13          225581.0    0.753584
# 13  14          220100.0    1.159845
# 14  15          225823.0    1.004997

# %%
ax = region_merge.plot(x="year_only", y="North-West Europe", legend=False)
ax2 = ax.twinx()
region_merge.plot(x="year_only", y="percentage", ax=ax2, legend=False, color="r", figsize=(15,8))
ax.figure.legend()
plt.show()

# %%
#add constant
region_merge = region_merge.assign(const=1)
#regression
y = region_merge['percentage']
X = region_merge[["const", "t", 'North-West Europe']] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     45.21
# Date:                Mon, 05 Oct 2020   Prob (F-statistic):           2.59e-06
# Time:                        17:40:52   Log-Likelihood:                 15.622
# No. Observations:                  15   AIC:                            -25.24
# Df Residuals:                      12   BIC:                            -23.12
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 1.0790      0.178      6.063      0.000       0.691       1.467
# t                     0.0446      0.006      7.807      0.000       0.032       0.057
# North-West Europe -2.617e-05   5.24e-06     -4.996      0.000   -3.76e-05   -1.48e-05
# ==============================================================================
# Omnibus:                        1.818   Durbin-Watson:                   2.720
# Prob(Omnibus):                  0.403   Jarque-Bera (JB):                1.417
# Skew:                           0.678   Prob(JB):                        0.492
# Kurtosis:                       2.343   Cond. No.                     2.34e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### Strong and statistically significant correlation with North_west Europe

# %%
#add constant
region_merge = region_merge.assign(const=1)
#regression
y = region_merge['percentage']
X = region_merge[["const", "t", "North Africa & the Middle East", 'Central Asia', 
                  'Southern Asia', 'Sub-Saharan Africa', 'North East Asia']] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     8.504
# Date:                Mon, 05 Oct 2020   Prob (F-statistic):            0.00403
# Time:                        17:40:03   Log-Likelihood:                 14.530
# No. Observations:                  15   AIC:                            -15.06
# Df Residuals:                       8   BIC:                            -10.10
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                              1.3568      0.417      3.251      0.012       0.395       2.319
# t                                  0.1456      0.045      3.269      0.011       0.043       0.248
# North Africa & the Middle East   -1.3e-05   1.22e-05     -1.063      0.319   -4.12e-05    1.52e-05
# Central Asia                    3.187e-05    6.1e-05      0.523      0.615      -0.000       0.000
# Southern Asia                  -2.156e-05   1.11e-05     -1.950      0.087   -4.71e-05    3.93e-06
# Sub-Saharan Africa             -2.409e-05   1.68e-05     -1.433      0.190   -6.29e-05    1.47e-05
# North East Asia                -2.141e-05   1.69e-05     -1.267      0.241   -6.04e-05    1.76e-05
# ==============================================================================
# Omnibus:                        1.737   Durbin-Watson:                   2.519
# Prob(Omnibus):                  0.420   Jarque-Bera (JB):                1.263
# Skew:                          -0.668   Prob(JB):                        0.532
# Kurtosis:                       2.515   Cond. No.                     7.02e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.02e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### dev'ing countries seem to be not statistically significant?

# %%
region_merge.columns
# Out:
# Index(['financial_year', 'Central Asia', 'North Africa & the Middle East',
#        'North East Asia', 'North-West Europe', 'Northern America', 'Oceania',
#        'South America, Central America & the Caribbean', 'South East Asia',
#        'Southern Asia', 'Southern and Eastern Europe', 'Sub-Saharan Africa',
#        'year_only', 't', 'total_immigrants', 'percentage', 'const'],
#       dtype='object')

# %%
#add constant
region_merge = region_merge.assign(const=1)
#regression
y = region_merge['percentage']
X = region_merge[["const", "t", 'North-West Europe']] #t represents time
lin_reg = sm.OLS(y, X)
results = lin_reg.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             percentage   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     45.21
# Date:                Mon, 05 Oct 2020   Prob (F-statistic):           2.59e-06
# Time:                        17:40:25   Log-Likelihood:                 15.622
# No. Observations:                  15   AIC:                            -25.24
# Df Residuals:                      12   BIC:                            -23.12
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 1.0790      0.178      6.063      0.000       0.691       1.467
# t                     0.0446      0.006      7.807      0.000       0.032       0.057
# North-West Europe -2.617e-05   5.24e-06     -4.996      0.000   -3.76e-05   -1.48e-05
# ==============================================================================
# Omnibus:                        1.818   Durbin-Watson:                   2.720
# Prob(Omnibus):                  0.403   Jarque-Bera (JB):                1.417
# Skew:                           0.678   Prob(JB):                        0.492
# Kurtosis:                       2.343   Cond. No.                     2.34e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
merged
# Out:
#    financial_year  total_immigrants  migr_news_perc  year_only   t  const
# 0      2002-07-01          125870.0        0.455606       2002   1      1
# 1      2003-07-01          148431.0        0.498948       2003   2      1
# 2      2004-07-01          162801.0        0.395300       2004   3      1
# 3      2005-07-01          174782.0        0.470755       2005   4      1
# 4      2006-07-01          190864.0        0.360467       2006   5      1
# 5      2007-07-01          203238.0        0.240773       2007   6      1
# 6      2008-07-01          219547.0        0.311291       2008   7      1
# 7      2009-07-01          203647.0        0.577675       2009   8      1
# 8      2010-07-01          207855.0        0.713295       2010   9      1
# 9      2011-07-01          237371.0        0.527310       2011  10      1
# 10     2012-07-01          246454.0        0.676470       2012  11      1
# 11     2013-07-01          235988.0        0.820838       2013  12      1
# 12     2014-07-01          225581.0        0.753584       2014  13      1
# 13     2015-07-01          220100.0        1.159845       2015  14      1
# 14     2016-07-01          225823.0        1.004997       2016  15      1

# %% [markdown]
# ### Make subset of developing country regions

# %%
subregion_deving = subregion[['financial_year', 'Central Asia', 'North Africa & the Middle East',
                              'South America, Central America & the Caribbean', 'South East Asia',
                              'Southern Asia', 'Sub-Saharan Africa', 'year_only', 't', 'total_immigrants']]

# %%
subregion_deving
# Out:
#    financial_year  Central Asia  North Africa & the Middle East  \
# 0      2002-07-01        1099.0                         11440.0
# 1      2003-07-01        1410.0                         12203.0
# 2      2004-07-01        1697.0                         13797.0
# 3      2005-07-01        2767.0                         12057.0
# 4      2006-07-01        2460.0                         10845.0
# 5      2007-07-01        1980.0                          9828.0
# 6      2008-07-01        1883.0                         12558.0
# 7      2009-07-01        1770.0                          9936.0
# 8      2010-07-01        2095.0                         11137.0
# 9      2011-07-01        1697.0                         11239.0
# 10     2012-07-01        2119.0                         12558.0
# 11     2013-07-01        4548.0                         14730.0
# 12     2014-07-01        3109.0                         16257.0
# 13     2015-07-01        2963.0                         14429.0
# 14     2016-07-01        3255.0                         28133.0
#
#     South America, Central America & the Caribbean  South East Asia  \
# 0                                           1955.0          21037.0
# 1                                           2166.0          22881.0
# 2                                           2392.0          23685.0
# 3                                           2677.0          24463.0
# 4                                           2585.0          26192.0
# 5                                           3046.0          28050.0
# 6                                           3362.0          29994.0
# 7                                           4086.0          30196.0
# 8                                           3479.0          30907.0
# 9                                           4121.0          34324.0
# 10                                          4532.0          34150.0
# 11                                          4438.0          31420.0
# 12                                          4085.0          31720.0
# 13                                          4207.0          32129.0
# 14                                          4788.0          31488.0
#
#     Southern Asia  Sub-Saharan Africa  year_only   t  total_immigrants
# 0         12910.0             10907.0       2002   1          125870.0
# 1         16662.0             13521.0       2003   2          148431.0
# 2         19692.0             14102.0       2004   3          162801.0
# 3         22506.0             12979.0       2005   4          174782.0
# 4         28476.0             14564.0       2006   5          190864.0
# 5         33002.0             15140.0       2007   6          203238.0
# 6         36024.0             19975.0       2008   7          219547.0
# 7         34761.0             20658.0       2009   8          203647.0
# 8         33828.0             16353.0       2010   9          207855.0
# 9         43190.0             16879.0       2011  10          237371.0
# 10        53429.0             13644.0       2012  11          246454.0
# 11        56307.0             12954.0       2013  12          235988.0
# 12        52814.0             12654.0       2014  13          225581.0
# 13        55328.0             11419.0       2015  14          220100.0
# 14        54980.0             11797.0       2016  15          225823.0

# %% [markdown]
# ### Make subset of developed country regions

# %%
subregion_devd = subregion[['financial_year', 'North-West Europe', 
                            'Northern America', 'Oceania', 
                            'Southern and Eastern Europe', 'North East Asia',  
                            'year_only', 't', 'total_immigrants']]

# %%
subregion_devd
# Out:
#    financial_year  North-West Europe  Northern America  Oceania  \
# 0      2002-07-01            22324.0            3670.0  16775.0
# 1      2003-07-01            29428.0            4012.0  19131.0
# 2      2004-07-01            30142.0            4128.0  22263.0
# 3      2005-07-01            35764.0            4410.0  23963.0
# 4      2006-07-01            36063.0            4201.0  28392.0
# 5      2007-07-01            37608.0            4332.0  33308.0
# 6      2008-07-01            39818.0            4619.0  32515.0
# 7      2009-07-01            33508.0            4802.0  24685.0
# 8      2010-07-01            28565.0            4471.0  34060.0
# 9      2011-07-01            36520.0            4963.0  42925.0
# 10     2012-07-01            32965.0            5525.0  41694.0
# 11     2013-07-01            33543.0            5494.0  29304.0
# 12     2014-07-01            31675.0            5058.0  24610.0
# 13     2015-07-01            27323.0            4977.0  22845.0
# 14     2016-07-01            25177.0            4931.0  16449.0
#
#     Southern and Eastern Europe  North East Asia  year_only   t  \
# 0                        6669.0          17084.0       2002   1
# 1                        5846.0          21171.0       2003   2
# 2                        5561.0          25342.0       2004   3
# 3                        5656.0          27540.0       2005   4
# 4                        5502.0          31584.0       2006   5
# 5                        5772.0          31172.0       2007   6
# 6                        6190.0          32609.0       2008   7
# 7                        6079.0          33166.0       2009   8
# 8                        5813.0          37147.0       2010   9
# 9                        6808.0          34705.0       2011  10
# 10                       7785.0          38053.0       2012  11
# 11                       7891.0          35359.0       2013  12
# 12                       7812.0          35787.0       2014  13
# 13                       7400.0          37080.0       2015  14
# 14                       7590.0          37235.0       2016  15
#
#     total_immigrants
# 0           125870.0
# 1           148431.0
# 2           162801.0
# 3           174782.0
# 4           190864.0
# 5           203238.0
# 6           219547.0
# 7           203647.0
# 8           207855.0
# 9           237371.0
# 10          246454.0
# 11          235988.0
# 12          225581.0
# 13          220100.0
# 14          225823.0

# %%
deving_merge = subregion_deving.merge(news_perc, left_on='financial_year', right_on='financial_year', copy = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-2c3afda05539> in <module>
# ----> 1 deving_merge = subregion_deving.merge(news_perc, left_on='financial_year', right_on='financial_year', copy = False)
#
# NameError: name 'subregion_deving' is not defined

# %%
deving_merge
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-a68e46468bdd> in <module>
# ----> 1 deving_merge
#
# NameError: name 'deving_merge' is not defined
